# %%
import random
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Minstd_rand: 647
# Mt19937: 699
# Mt19937_64: 555
# Ranlux48_base: 603
# Ranlux48: 9775
# Knuth_b: 731

# %%
generators = [
    "Minstd_rand", "Mt19937", "Mt19937_64",
    "Ranlux48_base", "Ranlux48", "Knuth_b"
]
results = [647, 699, 555, 603, 9775, 731]

indeksy = np.arange(len(generators))
szer_slupka = 0.80
plt.bar(indeksy, results, szer_slupka)
plt.xticks(indeksy, generators, rotation=45)
plt.ylabel('Czas (s)')
plt.show()
